# %%
import numpy as np
import itertools


from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

N = 10
L = 50

x = np.random.normal(size=N*L)
Rxx = np.empty([N, N])
for i in range(L):
    ordem = np.arange(N)
    Ri = np.empty([N, N])
    for tal in range(N):
        Ri[tal] = x[ordem * i] * x[(ordem * (i+1+tal)) % (N*L)]
    Rxx = Rxx + Ri
    
X, Y = np.meshgrid(np.arange(N), np.arange(N))
# Plot the surface.
fig = plt.figure()
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Rxx/L, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
plt.show()

# %%
N = 50
L = 500

x = np.random.normal(size=N*L)
Rxx = np.empty([N, N])
for i in range(L):
    ordem = np.arange(N)
    Ri = np.empty([N, N])
    for tal in range(N):
        Ri[tal] = x[ordem * i] * x[(ordem * (i+1+tal)) % (N*L)]
    Rxx = Rxx + Ri
    
X, Y = np.meshgrid(np.arange(N), np.arange(N))
# Plot the surface.
fig = plt.figure()
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Rxx/L, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
plt.show()

# %%
N = 100
L = 5000

x = np.random.normal(size=N*L)
Rxx = np.empty([N, N])
for i in range(L):
    ordem = np.arange(N)
    Ri = np.empty([N, N])
    for tal in range(N):
        Ri[tal] = x[ordem * i] * x[(ordem * (i+1+tal)) % (N*L)]
    Rxx = Rxx + Ri
    
X, Y = np.meshgrid(np.arange(N), np.arange(N))
# Plot the surface.
fig = plt.figure()
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Rxx/L, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
plt.show()
# Out:
# /home/ryuga/anaconda3/envs/PDS/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in add
#   # This is added back by InteractiveShellApp.init_path()
# /home/ryuga/anaconda3/envs/PDS/lib/python3.6/site-packages/matplotlib/colors.py:496: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)
