# %%
from zplane_utils import zplane
import scipy.signal as signal
import matplotlib.pyplot as plt
import matplotlib.colors as cores
import numpy as np

# %%
zplane([1], [1, -.8])
# Out:
# (array([], dtype=float64), array([ 0.8]))

# %%
w, X = signal.freqz([1], [1, -.8], whole=True)
print('b)')
plt.figure(figsize=(16, 4))
markerline, stemlines, baseline = plt.stem(w, np.angle(X), '--k', markerfmt='b.')
plt.setp(baseline, 'color', 'black', 'linewidth', 2)
plt.setp(stemlines, 'color', cores.to_rgba('black', .5))
plt.setp(markerline, 'color', cores.to_rgba(plt.getp(markerline, 'color'), .5))
plt.show()

plt.figure(figsize=(16, 4))
markerline, stemlines, baseline = plt.stem(w, np.absolute(X), '--k', markerfmt='b.')
plt.setp(baseline, 'color', 'black', 'linewidth', 2)
plt.setp(stemlines, 'color', cores.to_rgba('black', .5))
plt.setp(markerline, 'color', cores.to_rgba(plt.getp(markerline, 'color'), .5))
plt.show()
# Out:
# b)

# %%
signal.residuez([1, 1], [1, -.9, .81])
# Out:
# (array([ 0.5-0.93017543j,  0.5+0.93017543j]),
#  array([ 0.45+0.77942286j,  0.45-0.77942286j]),
#  array([ 0.]))

# %%
? signal.residuez

# %%
w, X = signal.freqz([1, -1, .25], [1, -.5])

print('e)')

plt.figure(figsize=(16, 4))
markerline, stemlines, baseline = plt.stem(w, np.angle(X), '--k', markerfmt='b.')
plt.setp(baseline, 'color', 'black', 'linewidth', 2)
plt.setp(stemlines, 'color', cores.to_rgba('black', .5))
plt.setp(markerline, 'color', cores.to_rgba(plt.getp(markerline, 'color'), .5))
plt.show()

plt.figure(figsize=(16, 4))
markerline, stemlines, baseline = plt.stem(w, np.absolute(X), '--k', markerfmt='b.')
plt.setp(baseline, 'color', 'black', 'linewidth', 2)
plt.setp(stemlines, 'color', cores.to_rgba('black', .5))
plt.setp(markerline, 'color', cores.to_rgba(plt.getp(markerline, 'color'), .5))
plt.show()
# Out:
# e)
